# %%
import pandas as pd

# %% [markdown]
# Datasets
#
# subject: topic of the dataset
# explanation: (statistical) of the dataset
# Download: link to download dataset
# Dataset: name of csv/xsl
# time: time-span of the observations
# measure: total number, %, categories (male, female, total etc)
# geo: geographical area of the data (OECD, EU, Spain CCAA etc)
#
#
# A World
#
# 1
# subject: satisfaction of population with educational system
# Download: https://www.oecd-ilibrary.org/sites/gov_glance-2017-82-en/index.html?itemId=/content/component/gov_glance-2017-82-en
# Dataset: OECD_satisfaction_educat_system.xlsx
# time: 2007 vs 2016
# measure: poll, %
# geo:
#
#
# 2
# subject: NEET OECD
# explanation:
# Download: https://data.oecd.org/youthinac/youth-not-in-employment-education-or-training-neet.htm
# Dataset: OECD_NEET.csv
# time:
# measure: T/ m/ f
# geo: OECD countries
#
# 3
# subject: Performance in 2015 PISA scores for students at age 15 and cumulative expenditure per student between 6 and 15 years old on education, 2013
# explanation:
# Download: https://www.oecd-ilibrary.org/governance/government-at-a-glance-2017_gov_glance-2017-en
# Dataset: OECD_score_PISA_2017_total.xlsx
# time: 2015
# measure: skills Reading/science 2015
# geo: OECD
#
# 4
# subject: Adult education level - Below upper secondary / Tertiary / Upper secondary, % of 25-64 year-olds, 2019
# explanation:
# Download: https://data.oecd.org/eduatt/adult-education-level.htm
# Dataset: OECD_educat_level_adults.csv
# time: 2000 - 2019
# measure: %
# geo: OECD
#
#
# 5
# subject: % of 15 year old students that achieve minimum PISA competence level 2
# explanation:
# Download: OCDE page
# Dataset: OCDE_difference_PISA_native_migrants
# time: 2018
# measure: %
# geo: OCDE 8 countries
#
# B Europe
#
#
# 1.
# subject: risk of poverty and social exclusion
# explanation: https://ec.europa.eu/eurostat/web/products-datasets/-/tgs00107
# Download: https://ec.europa.eu/eurostat/web/products-datasets/-/tgs00107
# Dataset: Eurostat_risk_poverty_exclusiom.tsv
# time: 2009 - 2020
# measure: %
# geo: Europe/ NUTS2 (????)
#
# 2.
# subject: underachieving pupils 15 years old
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/educ_outc_pisa_esms.htm
# Download: https://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=educ_outc_pisa&lang=en
# Dataset: Eurostat_underachieving15_PISA.tsv.gz
# time: 2003 - 2015 (rel. complete m/f), 2018 (only total)
# measure: %, 3 competence fields, region, m/f/T
# geo: country EU !!!! + SK, JP, USA, Russia
#
# > extra data for "normal"achieving pupils necessary for comparision?
#
# 3.
# subject: quality of employment, precarious jobs
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/lfsa_qoe_esms.htm
# Download: https://appsso.eurostat.ec.europa.eu/nui/setupDownloads.do
# Dataset: Eurostat_quality_labor_precarious.zip > as excel better readable
# time: 2010 - 2019
# measure: %
# geo: EU countries
#
#
# 4.
# subject: Low-wage earners as a proportion of all employees (excluding apprentices) by sex
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/earn_ses_main_esms.htm
# Download: https://db.nomics.world/Eurostat/earn_ses_pub1s
# Dataset: Eurostat_quality_labor_precarious.xls
# time: 2006 - 2018
# measure: %, m/f/Total
# geo: EU countries
#
# 5.
# subject: Employed persons having more than one job by sex [tqoe3a5]
# explanation: https://db.nomics.world/Eurostat/tqoe3a5
# Download: https://db.nomics.world/Eurostat/tqoe3a5
# Dataset: Eurostat_multiple_jobs.xlsx
# time: 2006 - 2018
# measure: %, m/f/T
# geo: EU countries
#
# > more data on job quality available: https://ec.europa.eu/eurostat/web/labour-market/quality-of-employment
#
# 6.
# subject: education finance (% of GDP)
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/educ_uoe_enr_esms.htm
# Download: https://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=educ_uoe_fine06&lang=en
# Dataset: Eurostat_spending_edu_GDP.xls
# time: 2012 - 2017
# measure: %
# geo: Europe
#
# 7.
# subject: Public expenditure on education per pupil/student based on FTE by education level and programme orientation[educ_uoe_fine09]
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/educ_uoe_enr_esms.htm
# Download: https://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=educ_uoe_fine09&lang=en
# Dataset: Eurostat_spending_edu_eur_p_pupil.xls
# time: 2012 - 2017
# measure: €
# geo: Europe
#
# 8.
# subject: Early leavers from education and training by sex and citizenship - born in Spain, but not Spanish nationality
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/edat1_esms.htm
# Download: https://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=edat_lfse_01&lang=en
# Dataset: Eurostat_early_leavers_citizenship.xls
# time: 2010 - 2019
# measure: % , total/ employed/ not employed
# geo: Europe
#
# 9.
# (subject: Early leavers from education and training by sex and labour status
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/lfst_hh_esms.htm
# Download: https://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=edat_lfse_14&lang=en
# Dataset: Eurostat_early_leavers_labourstatus.xls
# time:
# measure: rather unclear - ask profe
# geo:)
#
# 10
# subject: Early leavers from education and training by sex and country of birth - Ni Ni Ni (neither secondary, nor vocational training)
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/edat1_esms.htm
# Download: https://appsso.eurostat.ec.europa.eu/nui/setupDownloads.do
# Dataset: Eurostat_early_leavers_country_birth.xls
# time: 2010 - 2019
# measure: % early leavers of population (> born in country, but other nationality, 18-24 yrs)/ of employed/ unemployed
# geo: Europe
#
# 11
# subject: Early leavers from education and training by sex and NUTS 2 regions
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/edat1_esms.htm
# Download: https://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=edat_lfse_16&lang=en
# Dataset: Eurostat_early_leavers_NUTS2.xls
# time:
# measure:
# geo:
#
# > graphic solution: mapping NUTS Spain with precary labour and danger of social exclusion > map
#
# 12
# subject: Early leavers from education and training by sex and degree of urbanisation
# explanation: https://ec.europa.eu/eurostat/cache/metadata/en/edat1_esms.htm
# Download: https://ec.europa.eu/eurostat/databrowser/view/edat_lfse_30/default/table?lang=en
# Dataset: Eurostat_early_leavers_urban_cities.xlsx
# time: 2010 - 2019
# measure: one sheet per catagory - cities/ town/ rural
# geo: Europe
# schort analysis with graphics: https://ec.europa.eu/eurostat/statistics-explained/index.php/Early_leavers_from_education_and_training
#
# 13
# subject: Initial vocational training in enterprises per country, entreprises that emmploy VET students (= high percentage of dual VET)
# explanation:
# Download: https://ec.europa.eu/eurostat/statistics-explained/index.php?title=Vocational_education_and_training_statistics&oldid=504647
# Dataset: Eurostat_.enterprises_offering_VET.xlsx
# time: 2015
# measure: %
# geo: EU 27
# !!!! tabla 3 of the excel
#
#
# 14
# subject: How many students participate in work-based IVET (vocational training/ formación profesional)?
# explanation: https://www.cedefop.europa.eu/en/publications-and-resources/statistics-and-indicators/statistics-and-graphs/02-how-many-students-participate-work-based-ivet
# Download: same
# Dataset: CEDEFOP_students_IVET_countries.xlsx
# time: 2015
# measure: %
# geo: Europe
#
# > correlate with
#
#
# 15
# subject: Early leavers from education and training by sex and labour status (working, not empoyed, wants/doesn't want to work)
# explanation:
# Download: https://ec.europa.eu/eurostat/databrowser/view/EDAT_LFSE_14__custom_646826/default/table?lang=en
# Dataset: Eurostat_earl_leavers_labour_status_want_not_work.xlsx
# time: 2010 - 2019
# measure: &, f/m/ T, categories employed, not employed, wants to work etc...
# geo: EU 27
# beim download alle Boxen anklicken!!
#
#
# subject:
# explanation:
# Download:
# Dataset:
# time:
# measure:
# geo:
#
# subject:
# explanation:
# Download:
# Dataset:
# time:
# measure:
# geo:
#
#
#
#
#
#
#
#
#
# subject:
# explanation:
# Download:
# Dataset:
# time:
# measure:
# geo:
#
# Spain
#
# 1
# subject:  Abandono temprano de la educación-formación por comunidad  autónoma, sexo y periodo.
# explanation:
# Download: http://estadisticas.mecd.gob.es/EducaDynPx/educabase/index.htm?type=pcaxis&path=/laborales/epa/indi&file=pcaxis&l=s0#
# Dataset: ES_abandono_esc_CCAA.xls
# time: 2002 - 2020
# measure: % per CCAA, sex
# geo: Spain
#
#
#
# Cataluña
#
# subject: Abandonament prematur dels estudis (18-24 anys)
# explanation:
# Download: http://educacio.gencat.cat/ca/departament/estadistiques/indicadors/europeus/abandonament-prematur/
# Dataset: Generalitat_abandonament-prematur.xlsx
# time: 2001 - 2020 (Cat), - 2019 (EU)
# measure: %, Total/ f/ m
# geo: Cat
#
#
# Barcelona
#
# 1
# subject: Població estrangera per edats escolars, segons percentatge de presència al districte i en centres educatius de titularitat pública. Any = Gener de 2015
# explanation:
# Download: (pag. 32, 4.3 2016)
# Dataset: Bcn_infancia_2016_pop_stud_foreign_distr.xls
# time: 2015
# measure: %
# geo: Bcn
# clusterization/ ghettoisation foreign population in the same neighborhoods (even from other communities, as % students > % foreign population
#
#
# data report 2016
#
# table 1:
# Renda Familiar Disponible (RFD), percentatge de població major de 16 anys amb estudis superiors i percentatge de població
#
# table 2:
# Oferta de places públiques respecte el total de població 0-2 i demanda atesa, per districte. Any = 2015-2016
#
# table 4
#  Alumnat de P3 a 4t d’ESO amb beques de menjador, per districtes. Any = 2015-2016
#
# table 6:
# Percentatge d’alumnat de 4t d’ESO repetidor segons sexe i nacionalitat, per districtes. Any = 2015-2016
#
#
# data report 2019
# table 6
# % poblacio infantil I adolescents amb nationalitat estrangera sobre Barcelona (42756/246266)/ % sobre districte (Barcelona=17,4%)
#
# table 17.1
# deficiency in Catalan 12/15 yrs old students that do not pass the basic knowledge test
#
# table 17.2
# deficiency in Spanish 12/15 yrs old students that do not pass the basic knowledge test
#
# table 17.1
# deficiency in Maths 12/15 yrs old students that do not pass the basic knowledge test
#
# table 19
# Taxa de graduació a 4t d’ESO respecte dels alumnes matriculats segons sexe. Barcelona i districtes (Curs 2017/2018).
#
#
# to be made datasets:
#
# World
# subject: satisfaction of population with educational system
# Link: https://www.oecd-ilibrary.org/sites/gov_glance-2017-82-en/index.html?itemId=/content/component/gov_glance-2017-82-en
#
#
# Europe
#
# 1
# Data on the cost of NEET in the EU-21
# https://ec.europa.eu/assets/eac/education/experts-groups/2011-2013/esl/europe-esl-costs_en.pdf
# format: pdf
# material: cost in several countries, cost per EU country in % of GDP (p. 20)
#
# Satisfaction with VET system in European countries > combine with satisfaction educational system
#
# 2
# How many students participate in work-based IVET?
# https://www.cedefop.europa.eu/en/publications-and-resources/statistics-and-indicators/statistics-and-graphs/02-how-many-students-participate-work-based-ivet
#
#
# 3
# Image of VET in Europe - in graph
# https://www.cedefop.europa.eu/en/toolkits/vet-toolkit-tackling-early-leaving/resources/vet-toolkit-upskilling-pathways/best-practices/image-vet
#
#
# Spain
#
#
#
# Barcelona
#
#
#
# subject: pre-scholarization kids 0-2 years
#
#
# > hypothesis material El Peridodico art. 2, double as high in Sarria / Ciutat Vella or Nou Barris

# %% [markdown]
# Fragestellungen:
# Schulabbruch weltweit
#
# 1
#
# School abandon/ early leavers/ NEET (Nor in employment, training or education) World/ Europe/ Spain/ Barcelona
#
#
# definition: young people beyond compulsory schooling age who have not completed upper secondary education (Spain: ESO)
#
# A
# good structure (s. Material 1):
#
# causes
# a) socio-economic status
# b) migrant-minority background
# c) gender
# d) education system related factors
# - satisfaction with VET and educational system
# - schools with less ressources in needy neighborhoods with diverse/ difficult students (s. material 11 PISA y España)
# - language spoken at home (> visualisation) > phenomena still studied by science (easy languages vs. complicated, English as "world-language", pre-school/ kindergarden affinity of immigration communities)
#
#
#
# consequences:
# a) precarious and low-paid jobs, to draw on welfare
# b) difficulties in gaining a place in vocational training
# c) additional lifetime income for a student staying at school for an extra year at more than €70.000 (3 years = flat in Bcn)
# d) generates very large "social" costs (it has been shown to lead to later social breakdown, increased demand on the health system, and lower social cohesion)
# e) more prone to poor physical and mental health and may run a higher risk of anti-social behaviour and criminal activity - mostly girls suffer from self-esteem-problems and psychological problems (s Material 2)
#
#
# Hypothesis:
# World:
#
#
#
#
# - correlation vocational training share/ university-share
# - reputation and financing vocational training in several countries
# - theoretical vocational training vs. dual vocational training
# - cognitive faktors
# - climate
# - countryside/ urban areas
# - distribution of production sectors (availability of vulnerable employment and a vast low-wage-sector)
# - STEM subjects at school
# - sozio-economical factors (housing situation/ conditions (> surface, child's room on their own), parent's income, parent's origins)
# - investment in education in problematic communities/ neighborhoods (siehe Artikel "El Periodico")
# - kindergarden/ early education
# - vehicular language
# - private/ public tuition
# - age leaving parents' house
# - free school meals
# - relation suscription private schools/ public schools and migration (https://www.elperiodico.com/es/sociedad/20210203/alumnos-inmigrantes-expulsados-aulas-11496069)
# - measure abandon and spending in education (Dataset OECD Education and Training: https://stats.oecd.org/)
# - tasks comparative
#     file: C:\Users\dgruh\ironhack\assignments\week9\proyectofinal\datasets\EU_National_tasks_comparative , homepage: https://ec.europa.eu/jrc/en/publication/eur-scientific-and-technical-research-reports/comparative-national-tasks-database
#     https://www.bibb.de/de/134073.php
# - density of private tutoring schools (dataset ayuntamiento) > https://www.elperiodico.com/es/barcelona/20170412/fracaso-escolar--es--ocho-veces-mayor-ciutat-vella--que--sarria-sant-gervasi-5970054
# - find data on pre-scholarization in Catalunya/ Barcelona
# - percentage of people in risk of social exclusion by NUTS2 https://ec.europa.eu/eurostat/web/products-datasets/-/tgs00107
# - 8times Sarria - Raval: compare immigration %, GDP per head, private/ concertado schools per neighborhood
# - find data on consquences (wage loss for early leavers in later years)
# - correlation PISA/ NEET
#
#
# more time/ guinda pastel:
# webscrape Google maps academias "clases de refuerzo" (several pages) and correlate with neighborhoods with high/low share of students with difficulties

# %% [markdown]
# Material:
#
# 1
# EU report on early leavers:
# https://ec.europa.eu/programmes/erasmus-plus/project-result-content/ac1494bc-8a62-49ed-b874-052a75f29859/Early-school-leaving-factsheet.pdf
# - causes
# - consequences
#
# 2
# Abstract study psychological problems early leavers
# https://www.researchgate.net/publication/289293366_Psychological_problems_of_early_school_leavers
# - mostly girls with problems
#
# 3
# social exclusion: report Bancos de Alimentos - https://drive.google.com/file/d/1Wii_NKRYOwE9ibAJmj_xbazA3oxrafxb/view
# S. 13 Massnahmen für early leavers
# S. 6 factores claves de la exlusión y colectivos afectados)
#
# 4
# El Perdiodico
# a)
# title: Los alumnos extranjeros duplican la tasa del abandono escolar en España
# content: Un estudio señala que parte de los padres de alumnos españoles han dejado de confiar en la escuela pública por la presencia de inmigrantes
# link: https://www.elperiodico.com/es/sociedad/20210203/alumnos-inmigrantes-expulsados-aulas-11496069
# b)
# title: Un joven de Ciutat Vella tiene ocho veces más riesgo de fracaso escolar que uno de Sarrià
# link: https://www.elperiodico.com/es/barcelona/20170412/fracaso-escolar--es--ocho-veces-mayor-ciutat-vella--que--sarria-sant-gervasi-5970054
# content: La falta de equidad por nivel de renta que separa a unos distritos de otros se repite en educación
# Los barrios ricos duplican el porcentaje de niños escolarizados entre los cero y los dos años
#
# 5
# Immigrant background and expected early school leaving in Europe: evidence from PISA
# file:///D:/Descargas/jrc109065_techbrief_migesl_180202final.pdf
# long report with lots of statistical stuff on immigrants
# abstract: https://ec.europa.eu/jrc/en/publication/immigrant-background-and-expected-early-school-leaving-europe-evidence-pisa
#
# 6
# good oversight with short analysis and graphics NEET EU
# https://ec.europa.eu/eurostat/statistics-explained/index.php/Early_leavers_from_education_and_training
#
#
# 7
# cost of NEET for countries/ GDP - p. 10
# https://ec.europa.eu/assets/eac/education/experts-groups/2011-2013/esl/europe-esl-costs_en.pdf
#
# 8
# More data by Cedefop on attractiveness of VET (poll + Eurostat)
# https://www.cedefop.europa.eu/en/toolkits/vet-toolkit-tackling-early-leaving/intervention-approaches/improving-vet-image-and-attractiveness
#
# 9
# A Comparative national tasks database - analysis of skills in the workforce by country
# https://ec.europa.eu/jrc/sites/jrcsh/files/jrc122699.pdf
#
# 10
# Internationales Handbuch der Berufsbildung - Berufsbildungsreport Spanien bibb
# file:///D:/Descargas/5d5fc61160acb_IHBB_Spanien_2014_online%20(1).pdf
#
# 11
# PISA y España
# https://elpais.com/sociedad/2019/12/03/actualidad/1575328003_039914.html
# - PISA NO MIDE CÓMO INFLUYE LA DESIGUALDAD EN LAS REPETICIONES O EL ABANDONO ESCOLAR
# -  mayor escasez de materiales (libros, tecnología, bibliotecas, laboratorios…) y un menor número de profesores que los centros de otros barrios más privilegiados > España, el 53% de los centros con menos recursos dieron parte de esa situación, frente a un 22,6% de los institutos mejor posicionados. Un 30% de diferencia entre ambos tipos de centro, solo superado por Malta con el 39,9% y por Chipre, con el 53,4% (de 38 países que contestaron a esa cuestión).
#
# 12
# PISA and Spain - official resumee
# https://www.oecd.org/pisa/publications/PISA2018_CN_esp_ESP.pdf
# En España, los directores de centros educativos informan de media una gran escasez de
# personal y recursos comparado con la media de la OCDE. Además, los directores de centros
# educativos informan con más frecuencia una escasez de personal en centros desfavorecidos
# que en los favorecidos. En España, el 49% de los estudiantes están matriculados en centros
# desfavorecidos mientras que el 31% lo hacen en centros favorecidos cuyos directores han
# informado que la capacidad del centro educativo para proporcionar educación se ve
# obstaculizada, en cierta medida, por la falta de personal docente. De media entre los países
# de la OCDE, el 34% de los estudiantes en centros educativos desfavorecidos y el 18% de
# estudiantes de escuelas favorecidas asisten a centros como estos.

# %% [markdown]
# hypothesis:
# 1. students
# cognitive (PISA)
# risk of poverty and exclusion (child poverty)
#
# 2. parents
# socioeconomic:
# job quality
# low income
# multiple jobs
# risk of poverty and exclusion

# %% [markdown]
# weitergehende Fragestellungen/ Zukunft:
# - Automatisierung/ AI und skills für Anpassungsfähigkeit
# - graphic for other factors in the labor market to include: https://ec.europa.eu/eurostat/web/labour-market/quality-of-employment (gleich oben Schaubild)
# - ask kids about their wellbeing with school life as early indicator > ongoing project in Bcn > AI/ ML with other factors
# - AI Anwendungen project Argentina Nodes: Plataforma para la predicción de deserción escolar
# utilizando técnicas de inteligencia artificial, file:///D:/Descargas/NodesCIM2019.pdf

# %% [markdown]
# information:
# - charta 2020, < 10%

# %% [markdown]
# presentation:
#
# 1.
# - two teenies (one nini, one "normal" from Sarria) - 'What differenciates these 2 teenies - apart from the hoddie"?
# - O-Ton Youtube beide Fälle?
# > one has a degree, the other doesnt'
# > one from Sarria , one Raval
# > one has a times higher chance of dropping out
# > one is going to gain 1500€ less/ going to be able to afford a flat on his/ her own
#
# 2.
# UNICEF - education rights and positive trend (charts
#
# 2.
# Let's make a jorney through Europe with Leia and Mohammed to see what's going on > arrival Spain > welcome home, Barcelona (positiver Ausblick)
#
# 3.
# EU: charta 2020
# - charta 2020 signed by (presidente mit Flagge/Fackel) > Übergabe an Sánchez
#
# 4.
# social exclusion definition (Bilder von allen 9 und 4 auskreuzen:
# Severely materially deprived persons have living conditions severely constrained by a lack of resources, they experience at least 4 out of 9 following deprivations items: cannot afford
# i) to pay rent or utility bills,
# ii) keep home adequately warm,
# iii) face unexpected expenses,
# iv) eat meat, fish or a protein equivalent every second day,
# v) a week holiday away from home, vi) a car, vii) a washing machine,
# viii) a colour TV, or
# ix) a telephone.
#
# 5 mapping social exclusion/ early leavers
# > Armut wird per (Nicht)Bildung vererbt
# https://www.cidob.org/es/articulos/spain_in_focus/january_2013/the_pain_in_spain_increasing_inequality_and_poverty
#
#
#
#
# - end: in danger/ COVID number 165 mill students without school

# %% [markdown]
# Visualization
#
# 1
# Europe - NUTS 2 (= regions, CCAA)
# subject: share of early leavers in 2019 compared to 2020 charta goal
# Beispiel
# https://ec.europa.eu/eurostat/documents/4187653/10321620/EU-INSTA-MAP-EDUCATI0N-EARLY+LEAVERS.jpg/f71a5ddd-5243-fb44-dd4c-a84475b7e291?t=1601909979664
# > colour map Europe with "big 10%" charta or colour range <= 10 for countries who have achieved the goal
#
# 2
# Spain
# subject: early leavers evolution Spain
# x: time, 2010 - 2019
# y: % early leavers
# line: a) male/ b) female
# > line orange f, turquoise m
#
# 3
# Europe
# macroeconomic cost of early leavers
# comparison (3 times Denmark´s national budget > 3 x Denmark map)
#
#
# 4
# Europe
# subject: correlation education spending/ share of early leavers 2019
# x: spending % GDP on education
# y: % of early leavers 2019
# scatter points: countries
# > scatter plot
#
# 5
# Spain
# subject: correlation share early leavers/ share families in danger of social exclusiom
# - early leavers by CCAA
# - families in danger of social exclusion by CCAA
# a) dashboard with 2 heat maps or b) 1 interactive map with successive "mapping" of both phenomenas
#
# 6
# countries OECD Pisa
# subject: difference in PISA results between native students and students 1. generation immigration
# > dashboard
# a) horizontal bar graph: score native vs score immigrant by country, ascendant
# b) horizontal bar graph: difference between both scores per country, asscendant
#
# comparison bar within a bar/ stacked bar
#
# 7
# Barcelona
# subject: % of pupils with free meals per neighborhood/ % of pupils that repeat class
# a) city heatmap - preferible
# b) scatter plot
# x: free meals
# y: repeat class
# dots: neighborhoods
#
# easiest: map
#
# 8
# Barcelona
# subject: deficiency in catalan and maths at the 6a primaria (12 yrs) and 4a ESO (15 yrs)
# dashboard with 2 horizontal bar charts (cat + math) by neighboorhood and % od pupils that do not pass the basic knowledge test
# Dataset: bcn_informe_2019, 17.1 and 17.3.
#
# 9
# Barcelona
# "ghettoisation" of immigrant
# flow chart with 2 examples
#
# 10
# prediction model: time series forecasting
# a) Europe (tot, m, f) or
# b) Spain (CCAA)
#
#
# box-whisker-plot for Spain/ Barcelona
# bump charts

# %% [markdown]
# prediction model: time series forecasting
# modul: fbprophet
#
# 2 options:
# a) European countries based on last 10 years evolution for next 5 years to see whether each country will get close to 10% benchmark - total, male, female
#
# or
# b) Spanish CCAA (Autonomous communities) with huge differences to see when and whether 10% benchmark achievable

# %%
earl_leav_europe_10_19 = pd.read_excel(r'C:\Users\dgruh\ironhack\assignments\week9\proyecto final\datasets\Eurostat_early_leavers_pop_2010_2019.xls', skiprows = 11)
earl_leav_europe_10_19.head(20)
# Out:
#                                             GEO/TIME  2010  2011  2012  2013  \
# 0          European Union - 27 countries (from 2020)  13.8  13.2  12.6  11.8
# 1          European Union - 28 countries (2013-2020)  13.9  13.4  12.7  11.9
# 2          European Union - 15 countries (1995-2004)  15.3  14.7  13.7  12.7
# 3              Euro area - 19 countries  (from 2015)  15.4  14.6  13.8  12.8
# 4                                            Belgium  11.9  12.3  12.0  11.0
# 5                                           Bulgaria  12.6  11.8  12.5  12.5
# 6                                            Czechia   4.9   4.9   5.5   5.4
# 7                                            Denmark  11.5  10.3   9.6   8.2
# 8   Germany (until 1990 former territory of the FRG)  11.8  11.6  10.5   9.8
# 9                                            Estonia    11  10.6  10.3   9.7
# 10                                           Ireland  11.9  11.1   9.9   8.7
# ...

# %%
earl_leav_CCAA = pd.read_excel(r'C:\Users\dgruh\ironhack\assignments\week9\proyecto final\datasets\ES_abandono_esc_CCAA.xls', skiprows = 5)
earl_leav_CCAA.head(20)
# Out:
#                      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                    2019.0      2018.0      2017.0
# 1                         Total        17.3        17.9        18.3
# 2                     Andalucía        21.6        21.9        23.5
# 3                        Aragón        14.6        15.8        16.4
# 4       Asturias, Principado de        12.4        12.6        14.8
# 5                Balears, Illes        24.2        24.4        26.5
# 6                      Canarias        20.8        20.9        17.5
# 7                     Cantabria        12.8         9.8         8.9
# 8               Castilla y León        14.3        13.9        16.7
# 9          Castilla - La Mancha        20.2        20.5        22.1
# 10                     Cataluña        19.0        17.0        17.0
# 11         Comunitat Valenciana        16.4        20.2        20.3
# 12                  Extremadura        20.5        20.9        19.2
# ...

# %% [markdown]
# work process/ doucumenation
#
# 1. research/ investigation
#
#
# 2. data-wrangling
#
# a) datasets
# 4 geographical regions
# socioeconomic factors vs educational
#
# cleaning, deleting countries with few/ little reliable data
#
#
#
# 3. prediction model
# dependent variable: % early leavers
# independent: urbanization, labour status, gender,

# %%
statistical t-testing, f-tests, std of samples, p-value
